# %%
from dotenv import load_dotenv
import os
from google.cloud import dlp_v2
from google.cloud.dlp_v2 import types
from langchain_openai import ChatOpenAI
from langchain_community.agent_toolkits import create_sql_agent
from langchain_community.utilities import SQLDatabase
from langchain_experimental.utilities import PythonREPL
from langchain_core.example_selectors import SemanticSimilarityExampleSelector
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.messages import AIMessage
from langchain_core.prompts import (
    SystemMessagePromptTemplate,
    PromptTemplate,
    FewShotPromptTemplate,
)
from langchain_core.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    MessagesPlaceholder,
)

from langchain.memory import ConversationBufferMemory
from langchain.tools import Tool

# %%
load_dotenv()
# Out:
# True

# %%
# Setup

service_account_file = f"{os.getcwd()}/cns_dev_gcp.json"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = service_account_file

# %%
project='cdp-develop-347807'
dataset='pipst'
# Example Queries
sql_examples = [
    {
        "input": "Count of Customers by Source System",
        "query": f"""
            SELECT
                source_system_name,
                COUNT(*) AS customer_count
            FROM
                `{dataset}.customer`
            GROUP BY
                source_system_name
            ORDER BY
                customer_count DESC;
        """,
    },
    {
        "input": "Average Age of Customers by Gender",
        "query": f"""
            SELECT
                gender,
                AVG(EXTRACT(YEAR FROM CURRENT_DATE()) - EXTRACT(YEAR FROM dob)) AS average_age
            FROM
                `{dataset}.customer`
            GROUP BY
                gender;
        """,
    },
    {
        "input": "Count of Customers with Email and/or Phone",
        "query": f"""
            SELECT
                c.customer_key,
                c.first_name,
                c.last_name,
                SUM(CASE WHEN ct.type = 'email' THEN 1 ELSE 0 END) AS email_count,
                SUM(CASE WHEN ct.type = 'phone' THEN 1 ELSE 0 END) AS phone_count
            FROM
                `{dataset}.customer` c
            LEFT JOIN
                `{dataset}.contact` ct
            ON
                c.customer_key = ct.customer_key
            GROUP BY
                c.customer_key, c.first_name, c.last_name
            ORDER BY
                email_count DESC, phone_count DESC;
        """,
    },
    {
        "input": "List of Customers with Addresses",
        "query": f"""
            SELECT
                c.customer_key,
                c.first_name,
                c.last_name,
                a.full_address,
                a.state,
                a.country
            FROM
                `{dataset}.customer` c
            JOIN
                `{dataset}.customer_address` ca
            ON
                c.customer_key = ca.customer_key
            JOIN
                `{dataset}.address` a
            ON
                ca.address_key = a.address_key;
        """,
    },
    {
        "input": "Job States Summary",
        "query": f"""
            SELECT
                batch_id,
                status,
                record_count,
                load_timestamp,
                JSON_EXTRACT_SCALAR(job_summary, '$.SYS1') AS sys1_count,
                JSON_EXTRACT_SCALAR(job_summary, '$.SYS2') AS sys2_count,
                JSON_EXTRACT_SCALAR(job_summary, '$.SYS3') AS sys3_count,
                JSON_EXTRACT_SCALAR(job_summary, '$.SYS4') AS sys4_count,
                JSON_EXTRACT_SCALAR(job_summary, '$.SYS5') AS sys5_count
            FROM
                `{dataset}.job_states`
            ORDER BY
                load_timestamp DESC;
        """,
    },
    {
        "input": "Top 5 Most Populated States",
        "query": f"""
            SELECT
                state,
                COUNT(*) AS address_count
            FROM
                `{dataset}.address`
            GROUP BY
                state
            ORDER BY
                address_count DESC
            LIMIT 5;
        """,
    },
    {
        "input": "Total Contacts (Emails and Phones) by Source System",
        "query": f"""
            SELECT
                c.source_system_name,
                SUM(CASE WHEN ct.type = 'email' THEN 1 ELSE 0 END) AS total_emails,
                SUM(CASE WHEN ct.type = 'phone' THEN 1 ELSE 0 END) AS total_phones
            FROM
                `{dataset}.customer` c
            JOIN
                `{dataset}.contact` ct
            ON
                c.customer_key = ct.customer_key
            GROUP BY
                c.source_system_name;
        """,
    },
    {
        "input": "Distribution of Customers by Age Groups",
        "query": f"""
            SELECT
                CASE
                    WHEN age < 20 THEN 'Under 20'
                    WHEN age BETWEEN 20 AND 29 THEN '20-29'
                    WHEN age BETWEEN 30 AND 39 THEN '30-39'
                    WHEN age BETWEEN 40 AND 49 THEN '40-49'
                    WHEN age BETWEEN 50 AND 59 THEN '50-59'
                    ELSE '60 and above'
                END AS age_group,
                COUNT(*) AS customer_count
            FROM
                (SELECT
                    EXTRACT(YEAR FROM CURRENT_DATE()) - EXTRACT(YEAR FROM dob) AS age
                FROM
                    `{dataset}.customer`)
            GROUP BY
                age_group
            ORDER BY
                customer_count DESC;
        """,
    },
    {
        "input": "Customers with Multiple Source Systems",
        "query": f"""
            SELECT
                first_name,
                last_name,
                COUNT(DISTINCT source_system_name) AS source_system_count
            FROM
                `{dataset}.customer`
            GROUP BY
                first_name, last_name
            HAVING
                source_system_count > 1;
        """,
    },
    {
        "input": "Recent Job Runs with Their Status",
        "query": f"""
            SELECT
                batch_id,
                status,
                record_count,
                load_timestamp
            FROM
                `{dataset}.job_states`
            ORDER BY
                load_timestamp DESC
            LIMIT 10;
        """,
    },
]


PREFIX = """
You are a SQL expert. You have access to a BigQuery database.
Identify which tables can be used to answer the user's question and write and execute a SQL query accordingly.
Given an input question, create a syntactically correct SQL query to run against the dataset customer_profiles, then look at the results of the query and return the answer.
Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most {top_k} results.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table; only ask for the relevant columns given the question.
You have access to tools for interacting with the database.
Only use the information returned by these tools to construct your final answer.
You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.

If the question does not seem related to the database, just return "I don't know" as the answer.

If the user asks for a visualization of the results, use the python_agent tool to create and display the visualization.

After obtaining the results, you must use the mask_pii_data tool to mask the results before providing the final answer.
"""

SUFFIX = """Begin!

{chat_history}

Question: {input}
Thought: I should look at the tables in the database to see what I can query.  Then I should query the schema of the most relevant tables.
{agent_scratchpad}"""

# %%
def mask_pii_data(text):
    dlp = dlp_v2.DlpServiceClient()

    project_id = project
    parent = f"projects/{project_id}"

    info_types = [
        {"name": "EMAIL_ADDRESS"},
        {"name": "PHONE_NUMBER"},
        {"name": "DATE_OF_BIRTH"},
        {"name": "LAST_NAME"},
        {"name": "STREET_ADDRESS"},
        {"name": "LOCATION"},
    ]

    deidentify_config = types.DeidentifyConfig(
        info_type_transformations=types.InfoTypeTransformations(
            transformations=[
                types.InfoTypeTransformations.InfoTypeTransformation(
                    primitive_transformation=types.PrimitiveTransformation(
                        character_mask_config=types.CharacterMaskConfig(
                            masking_character="*", number_to_mask=0, reverse_order=False
                        )
                    )
                )
            ]
        )
    )

    item = {"value": text}
    inspect_config = {"info_types": info_types}
    request = {
        "parent": parent,
        "inspect_config": inspect_config,
        "deidentify_config": deidentify_config,
        "item": item,
    }

    response = dlp.deidentify_content(request=request)

    return response.item.value


python_repl = PythonREPL()

# %%
def sql_agent_tools():
    tools = [
        Tool.from_function(
            func=mask_pii_data,
            name="mask_pii_data",
            description="Masks PII data in the input text using Google Cloud DLP.",
        ),
        Tool(
            name="python_repl",
            description=f"A Python shell. Use this to execute python commands. \
              Input should be a valid python command. \
              If you want to see the output of a value, \
              you should print it out with `print(...)`.",
            func=python_repl.run,
        ),
    ]
    return tools

# %%
example_selector = SemanticSimilarityExampleSelector.from_examples(
    sql_examples,
    OpenAIEmbeddings(),
    FAISS,
    k=2,
    input_keys=["input"],
)

# %%
few_shot_prompt = FewShotPromptTemplate(
    example_selector=example_selector,
    example_prompt=PromptTemplate.from_template(
        "User input: {input}\nSQL query: {query}"
    ),
    prefix=PREFIX,
    suffix="",
    input_variables=["input", "top_k"],
    example_separator="\n\n",
)

# %%
messages = [
    SystemMessagePromptTemplate(prompt=few_shot_prompt),
    MessagesPlaceholder(variable_name="chat_history"),
    HumanMessagePromptTemplate.from_template("{input}"),
    AIMessage(content=SUFFIX),
    MessagesPlaceholder(variable_name="agent_scratchpad"),
]
prompt = ChatPromptTemplate.from_messages(messages)

# %%
extra_tools = sql_agent_tools()

# %%
memory = ConversationBufferMemory(
    memory_key="chat_history", return_messages=True, input_key="input"
)

# %%
# Connect to your Google BigQuery database
# db = SQLDatabase.from_uri("bigquery://cdp-develop-347807")
bigquery_url = f'bigquery://{project}/{dataset}?credentials_path={service_account_file}'
db = SQLDatabase.from_uri(bigquery_url)

# %%
# Create a language model
# llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
model = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
# Create the agent executor
agent_executor = create_sql_agent(
    llm=model,
    db=db,
    verbose=True,
    top_k=3,
    prompt=prompt,
    extra_tools=extra_tools,
    input_variables=["input", "agent_scratchpad", "chat_history"],
    agent_type="openai-tools",
    agent_executor_kwargs={"handle_parsing_errors": True, "memory": memory},
)

# %%
agent_executor.invoke("고객이름이 들어간 테이블은 뭐야?")
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# l0lc_attr_campaign_m, l0lc_attribute_custom_key, l0lc_attribute_custom_key_affiliate, l0lc_attribute_custom_key_bigquery, l0lc_behv_app_custom_key, l0lc_behv_app_custom_key_affiliate, l0lc_behv_app_custom_key_bigquery, l0lc_behv_purchase_custom_key, l0lc_behv_purchase_custom_key_affiliate, l0lc_behv_purchase_custom_key_bigquery, l0lc_campaign, l0lc_cdp_ingestion, l0lc_cdp_ingestion_affiliate, l0lc_cdp_ingestion_bigquery, l0lc_cdp_ingestion_redshift, l0lc_cdp_ingestion_test, l0lc_cust_attr_info, l0lc_cust_attr_info_affiliate, l0lc_cust_attr_info_bigquery, l0lc_cust_buy_info, l0lc_cust_buy_info_affiliate, l0lc_cust_buy_info_bigquery, l0lc_e_commerce_attributes, l0lc_e_commerce_attributes_1000k, l0lc_e_commerce_attributes_1000k_affiliate, l0lc_e_commerce_attributes_1000k_no_oneid, l0lc_e_commerce_attributes_1000k_no_oneid_affiliate, l0lc_e_commerce_attributes_10k, l0lc_e_commerce_attributes_10k_affiliate, l0lc_e_commerce_attributes_1k, l0lc_e_commerce_attributes_1k_affiliate, l0lc_e_commerce_shopping, l0lc_e_commerce_shopping_affiliate, l0lc_e_commerce_shopping_no_oneid, l0lc_e_commerce_shopping_no_oneid_affiliate, l0lc_membership_custom_key, l0lc_membership_custom_key_affiliate, l0lc_membership_custom_key_bigquery, l0lc_performance_metrics, l0lc_product_catalog, l0lc_time_test, l0lc_time_test_affiliate, l0lc_time_test_bigquery, l0lc_time_test_copy, zzz_hso_affiliate_branch_mst
# Invoking: `sql_db_schema` with `{'table_names': 'l0lc_cust_attr_info, l0lc_cust_buy_info, l0lc_e_commerce_attributes'}`
#
#
#
# CREATE TABLE `l0lc_cust_attr_info` (
# 	`cust_no` STRING,
# 	`nam` STRING,
# 	`mbltlno` STRING,
# 	`emal_addr` STRING,
# 	`CI` STRING,
# 	`brno` STRING,
# 	`gendr` STRING,
# 	`age` INT64,
# 	`frgr_yn` STRING,
# 	`ntnl` STRING,
# 	`badr` STRING,
# 	`loc_info` STRING,
# 	`lgin_id` STRING,
# 	`time` STRING
# )
#
# /*
# 3 rows from l0lc_cust_attr_info table:
# cust_no	nam	mbltlno	emal_addr	CI	brno	gendr	age	frgr_yn	ntnl	badr	loc_info	lgin_id	time
# c_youjkim	김유정	010-4714-3436	youjkim@lgcns.com	None	None	F	22	false	한국	서울특별시 강서구 마곡중앙10로 70 마곡_E14(연구동) 6층	None	youjkim	20230824053034
# c_youjkim	김유정	010-4714-3436	youjkim@lgcns.com	None	None	F	22	false	한국	서울특별시 강서구 마곡중앙10로 70 마곡_E14(연구동) 6층	None	youjkim@lgcns.com	20230824053034
# c_kimes	김은숙	010-2077-5664	kimes@lgcns.com	None	None	F	30	false	한국	서울특별시 강서구 마곡중앙10로 70 마곡_E14(연구동) 6층	None	obtest005@lgcns.com	20230824053034
# */
#
#
# CREATE TABLE `l0lc_cust_buy_info` (
# 	`cust_no` STRING,
# 	`thyy_buy_qt` INT64,
# 	`thyy_buy_amt` INT64,
# 	`rcnt_5fyer_buy_qt` INT64,
# 	`rcnt_5fyer_buy_amt` INT64,
# 	`rcnt_buy_dt` INT64,
# 	`rcnt_buy_amt` INT64,
# 	`time` STRING
# )
#
# /*
# 3 rows from l0lc_cust_buy_info table:
# cust_no	thyy_buy_qt	thyy_buy_amt	rcnt_5fyer_buy_qt	rcnt_5fyer_buy_amt	rcnt_buy_dt	rcnt_buy_amt	time
# c_kimes	255	255000	1275	1275000	0	0	20220523112448
# c_sunoj	0	0	5	5000	0	0	20220523112448
# c_youjkim	1	1000	5	5000	0	0	20220523112448
# */
#
#
# CREATE TABLE `l0lc_e_commerce_attributes` (
# 	`UID` STRING,
# 	`Gender` STRING,
# 	`Age` INT64,
# 	`firstname` STRING,
# 	`lastname` STRING,
# 	`address` STRING,
# 	`email` STRING,
# 	`birthdate` DATE,
# 	`phone` STRING,
# 	`LocalTime` TIMESTAMP,
# 	`time` STRING
# )
#
# /*
# 3 rows from l0lc_e_commerce_attributes table:
# UID	Gender	Age	firstname	lastname	address	email	birthdate	phone	LocalTime	time
# 65322779	m	20	Eve	Brown	303 Cedar St	gwqfm@example.com	2011-07-10	254-680-4754	None	2024-07-18 05:52:27
# 70750337	f	20	Charlie	Brown	456 Elm St	pjsjw@example.com	1991-03-19	588-739-2036	None	2024-07-18 05:52:27
# 64939806	f	20	Charlie	Brown	101 Oak St	tydfi@example.com	2016-09-16	248-130-6459	None	2024-07-18 05:52:27
# */고객 이름이 포함된 테이블은 `l0lc_cust_attr_info`와 `l0lc_e_commerce_attributes`입니다.
#
# - `l0lc_cust_attr_info` 테이블에는 `nam` 열이 고객 이름을 나타냅니다.
# - `l0lc_e_commerce_attributes` 테이블에는 `firstname`과 `lastname` 열이 고객 이름을 나타냅니다.
#
# > Finished chain.
# {'input': '고객이름이 들어간 테이블은 뭐야?',
#  'chat_history': [HumanMessage(content='고객이름이 들어간 테이블은 뭐야?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='고객 이름이 포함된 테이블은 `l0lc_cust_attr_info`와 `l0lc_e_commerce_attributes`입니다. \n\n- `l0lc_cust_attr_info` 테이블에는 `nam` 열이 고객 이름을 나타냅니다.\n- `l0lc_e_commerce_attributes` 테이블에는 `firstname`과 `lastname` 열이 고객 이름을 나타냅니다.', additional_kwargs={}, response_metadata={})],
#  'output': '고객 이름이 포함된 테이블은 `l0lc_cust_attr_info`와 `l0lc_e_commerce_attributes`입니다. \n\n- `l0lc_cust_attr_info` 테이블에는 `nam` 열이 고객 이름을 나타냅니다.\n- `l0lc_e_commerce_attributes` 테이블에는 `firstname`과 `lastname` 열이 고객 이름을 나타냅니다.'}

# %%
agent_executor.invoke("여성 고객 수를 구하는 SQL query는 뭐야?")
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# l0lc_attr_campaign_m, l0lc_attribute_custom_key, l0lc_attribute_custom_key_affiliate, l0lc_attribute_custom_key_bigquery, l0lc_behv_app_custom_key, l0lc_behv_app_custom_key_affiliate, l0lc_behv_app_custom_key_bigquery, l0lc_behv_purchase_custom_key, l0lc_behv_purchase_custom_key_affiliate, l0lc_behv_purchase_custom_key_bigquery, l0lc_campaign, l0lc_cdp_ingestion, l0lc_cdp_ingestion_affiliate, l0lc_cdp_ingestion_bigquery, l0lc_cdp_ingestion_redshift, l0lc_cdp_ingestion_test, l0lc_cust_attr_info, l0lc_cust_attr_info_affiliate, l0lc_cust_attr_info_bigquery, l0lc_cust_buy_info, l0lc_cust_buy_info_affiliate, l0lc_cust_buy_info_bigquery, l0lc_e_commerce_attributes, l0lc_e_commerce_attributes_1000k, l0lc_e_commerce_attributes_1000k_affiliate, l0lc_e_commerce_attributes_1000k_no_oneid, l0lc_e_commerce_attributes_1000k_no_oneid_affiliate, l0lc_e_commerce_attributes_10k, l0lc_e_commerce_attributes_10k_affiliate, l0lc_e_commerce_attributes_1k, l0lc_e_commerce_attributes_1k_affiliate, l0lc_e_commerce_shopping, l0lc_e_commerce_shopping_affiliate, l0lc_e_commerce_shopping_no_oneid, l0lc_e_commerce_shopping_no_oneid_affiliate, l0lc_membership_custom_key, l0lc_membership_custom_key_affiliate, l0lc_membership_custom_key_bigquery, l0lc_performance_metrics, l0lc_product_catalog, l0lc_time_test, l0lc_time_test_affiliate, l0lc_time_test_bigquery, l0lc_time_test_copy, zzz_hso_affiliate_branch_mst
# Invoking: `sql_db_schema` with `{'table_names': 'l0lc_cust_attr_info, l0lc_e_commerce_attributes'}`
#
#
#
# CREATE TABLE `l0lc_cust_attr_info` (
# 	`cust_no` STRING,
# 	`nam` STRING,
# 	`mbltlno` STRING,
# 	`emal_addr` STRING,
# 	`CI` STRING,
# 	`brno` STRING,
# 	`gendr` STRING,
# 	`age` INT64,
# 	`frgr_yn` STRING,
# 	`ntnl` STRING,
# 	`badr` STRING,
# 	`loc_info` STRING,
# 	`lgin_id` STRING,
# 	`time` STRING
# )
#
# /*
# 3 rows from l0lc_cust_attr_info table:
# cust_no	nam	mbltlno	emal_addr	CI	brno	gendr	age	frgr_yn	ntnl	badr	loc_info	lgin_id	time
# c_youjkim	김유정	010-4714-3436	youjkim@lgcns.com	None	None	F	22	false	한국	서울특별시 강서구 마곡중앙10로 70 마곡_E14(연구동) 6층	None	youjkim	20230824053034
# c_youjkim	김유정	010-4714-3436	youjkim@lgcns.com	None	None	F	22	false	한국	서울특별시 강서구 마곡중앙10로 70 마곡_E14(연구동) 6층	None	youjkim@lgcns.com	20230824053034
# c_kimes	김은숙	010-2077-5664	kimes@lgcns.com	None	None	F	30	false	한국	서울특별시 강서구 마곡중앙10로 70 마곡_E14(연구동) 6층	None	obtest005@lgcns.com	20230824053034
# */
#
#
# CREATE TABLE `l0lc_e_commerce_attributes` (
# 	`UID` STRING,
# 	`Gender` STRING,
# 	`Age` INT64,
# 	`firstname` STRING,
# 	`lastname` STRING,
# 	`address` STRING,
# 	`email` STRING,
# 	`birthdate` DATE,
# 	`phone` STRING,
# 	`LocalTime` TIMESTAMP,
# 	`time` STRING
# )
#
# /*
# 3 rows from l0lc_e_commerce_attributes table:
# UID	Gender	Age	firstname	lastname	address	email	birthdate	phone	LocalTime	time
# 65322779	m	20	Eve	Brown	303 Cedar St	gwqfm@example.com	2011-07-10	254-680-4754	None	2024-07-18 05:52:27
# 70750337	f	20	Charlie	Brown	456 Elm St	pjsjw@example.com	1991-03-19	588-739-2036	None	2024-07-18 05:52:27
# 64939806	f	20	Charlie	Brown	101 Oak St	tydfi@example.com	2016-09-16	248-130-6459	None	2024-07-18 05:52:27
# */여성 고객 수를 구하기 위해 `l0lc_cust_attr_info` 테이블의 `gendr` 열과 `l0lc_e_commerce_attributes` 테이블의 `Gender` 열을 사용할 수 있습니다. 다음은 여성 고객 수를 구하는 SQL 쿼리입니다:
#
# ```sql
# SELECT
#     COUNT(*) AS female_customer_count
# FROM
#     (
#         SELECT gendr AS gender FROM `l0lc_cust_attr_info`
#         UNION ALL
#         SELECT Gender AS gender FROM `l0lc_e_commerce_attributes`
#     ) AS combined
# WHERE
#     gender = 'F' OR gender = 'f';
# ```
#
# 이 쿼리는 두 테이블에서 성별이 'F' 또는 'f'인 고객의 수를 합산하여 반환합니다.
#
# > Finished chain.
# {'input': '여성 고객 수를 구하는 SQL query는 뭐야?',
#  'chat_history': [HumanMessage(content='고객이름이 들어간 테이블은 뭐야?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='고객 이름이 포함된 테이블은 `l0lc_cust_attr_info`와 `l0lc_e_commerce_attributes`입니다. \n\n- `l0lc_cust_attr_info` 테이블에는 `nam` 열이 고객 이름을 나타냅니다.\n- `l0lc_e_commerce_attributes` 테이블에는 `firstname`과 `lastname` 열이 고객 이름을 나타냅니다.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='여성 고객 수를 구하고 싶어. SQL문으로 알려줘.', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='여성 고객의 수는 11명입니다.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='여성 고객 수를 구하는 SQL query는 뭐야?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="여성 고객 수를 구하기 위해 `l0lc_cust_attr_info` 테이블의 `gendr` 열과 `l0lc_e_commerce_attributes` 테이블의 `Gender` 열을 사용할 수 있습니다. 다음은 여성 고객 수를 구하는 SQL 쿼리입니다:\n\n```sql\nSELECT \n    COUNT(*) AS female_customer_count\nFROM \n    (\n        SELECT gendr AS gender FROM `l0lc_cust_attr_info`\n        UNION ALL\n        SELECT Gender AS gender FROM `l0lc_e_commerce_attributes`\n    ) AS combined\nWHERE \n    gender = 'F' OR gender = 'f';\n```\n\n이 쿼리는 두 테이블에서 성별이 'F' 또는 'f'인 고객의 수를 합산하여 반환합니다.", additional_kwargs={}, response_metadata={})],
#  'output': "여성 고객 수를 구하기 위해 `l0lc_cust_attr_info` 테이블의 `gendr` 열과 `l0lc_e_commerce_attributes` 테이블의 `Gender` 열을 사용할 수 있습니다. 다음은 여성 고객 수를 구하는 SQL 쿼리입니다:\n\n```sql\nSELECT \n    COUNT(*) AS female_customer_count\nFROM \n    (\n        SELECT gendr AS gender FROM `l0lc_cust_attr_info`\n        UNION ALL\n        SELECT Gender AS gender FROM `l0lc_e_commerce_attributes`\n    ) AS combined\nWHERE \n    gender = 'F' OR gender = 'f';\n```\n\n이 쿼리는 두 테이블에서 성별이 'F' 또는 'f'인 고객의 수를 합산하여 반환합니다."}
